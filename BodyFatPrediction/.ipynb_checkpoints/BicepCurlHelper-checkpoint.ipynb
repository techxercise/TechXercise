# %% [markdown]
# # Setting up Media Pipe

# %%
# Importing libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils # Drawing Utilites
mp_pose = mp.solutions.pose # Pose
mp_holistic = mp.solutions.holistic # Holistic
# %matplotlib inline

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False # Image is no longer writeable
    results = model.process(image) # Make prediction
    image.flags.writeable = True # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks_right(image, results):
    # Draw right pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, [list(mp_holistic.POSE_CONNECTIONS)[18], list(mp_holistic.POSE_CONNECTIONS)[4], list(mp_holistic.POSE_CONNECTIONS)[30]], 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=3, circle_radius=3)
                             )
    
def draw_styled_landmarks_left(image,results):
    # Draw left pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, [list(mp_holistic.POSE_CONNECTIONS)[22], list(mp_holistic.POSE_CONNECTIONS)[34]],
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=3, circle_radius=3)
                             )

# %% [markdown]
# # Anaylzing Correct Weightlifting Angle

# %%
class Rating:
    def __init__(self,a,b,c):
        self.a = np.array(a)
        self.b = np.array(b)
        self.c = np.array(c)
        self.radians = np.arctan2(self.c[1]-self.b[1], self.c[0]-self.b[0]) - np.arctan2(self.a[1]-self.b[1], self.a[0]-self.b[0])
        self.angle = np.abs(self.radians*180.0/np.pi)
        
    def calculate_angle(self):
        if self.angle > 180.0:
            self.angle = 360-self.angle
            
        return self.angle

# %%
plt.figure(figsize=(12,6))

correct1 = cv2.imread('Correct_1.jpeg')

plt.plot([115,100],[375,55],'c',linewidth=2)
plt.plot([185,100],[385,55],'c',linewidth=2)

# Calculate angle
obj = Rating([115,375],[100,55],[185,385])
angle = obj.calculate_angle()

plt.imshow(cv2.cvtColor(correct1, cv2.COLOR_BGR2RGB))
print("The angle is: " + str(angle))
# Out:
# The angle is: 11.760260565023254

# %%
plt.figure(figsize=(12,6))

correct2 = cv2.imread('Correct_2.jpeg')

plt.plot([330,345],[250,50],'c',linewidth=2)
plt.plot([290,345],[235,50],'c',linewidth=2)

# Calculate angle
obj = Rating([330,250],[350,40],[290,235])
angle = obj.calculate_angle()

plt.imshow(cv2.cvtColor(correct2, cv2.COLOR_BGR2RGB))
print("The angle is: " + str(angle))
# Out:
# The angle is: 11.662396938046864

# %%
plt.figure(figsize=(12,6))

correct3 = cv2.imread('Correct_3.jpeg')

plt.plot([260,310],[475,240],'c',linewidth=2)
plt.plot([220,310],[440,240],'c',linewidth=2)

# Calculate angle
obj = Rating([260,475],[310,240],[220,440])
angle = obj.calculate_angle()

plt.imshow(cv2.cvtColor(correct3, cv2.COLOR_BGR2RGB))
print("The angle is: " + str(angle))
# Out:
# The angle is: 12.216266931588724

# %%
plt.figure(figsize=(12,6))

correct4 = cv2.imread('Correct_4.jpeg')

plt.plot([320,380],[290,60],'c',linewidth=2)
plt.plot([285,380],[265,60],'c',linewidth=2)

# Calculate angle
obj = Rating([320,290],[380,60],[285,265])
angle = obj.calculate_angle()

plt.imshow(cv2.cvtColor(correct4, cv2.COLOR_BGR2RGB))
print("The angle is: " + str(angle))
# Out:
# The angle is: 10.242822583120212

# %% [markdown]
# The mean of all the observed angles is 11.47. That will be the angle used to determine the percentage.

# %%
class Rating:
    def __init__(self,a,b,c):
        self.a = np.array(a)
        self.b = np.array(b)
        self.c = np.array(c)
        self.radians = np.arctan2(self.c[1]-self.b[1], self.c[0]-self.b[0]) - np.arctan2(self.a[1]-self.b[1], self.a[0]-self.b[0])
        self.angle = np.abs(self.radians*180.0/np.pi)
        
    def calculate_angle(self):
        if self.angle > 180.0:
            self.angle = 360-self.angle
            
        return self.angle
    
    def calculate_rating(self):
        if self.angle > 180.0:
            self.angle = 360-self.angle
            
        if self.angle >= 11.47:
            percentage = 100 * (11.47/self.angle)
        else:
            self.angle = 22.94 - self.angle
            percentage = 100 * (11.47/self.angle)
        
        return percentage

# %% [markdown]
# # Real Time Weightlifting Detection

# %%
# Right Arm

cap = cv2.VideoCapture(0)
cnt = 0
curl_stage = None

# Access mediapipe model
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
# Set mediapipe model 
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = pose.process(image)
        
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw landmarks
        draw_styled_landmarks_right(image, results)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            face = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            
            # Calculate percentage
            obj = Rating(hip,shoulder,elbow)
            percentage = obj.calculate_rating()
            the_angle = obj.calculate_angle()
            
            if percentage > 80:
                cv2.putText(image, "Great: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            if percentage < 80 and percentage > 60:
                cv2.putText(image, "Could be better: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            if percentage < 60 and the_angle > 5:
                cv2.putText(image, "Please adjust your arm: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            
            # Calculate angle for counter
            obj1 = Rating(shoulder,elbow,wrist)
            angle = obj1.calculate_angle()
            
            if angle > 150 and percentage > 80:
                curl_stage = 'down'
            if angle < 40 and curl_stage == 'down':
                curl_stage = 'up'
                cnt += 1
                
        except:
            pass
        
        # Rectangle Setup on Top
        cv2.rectangle(image, (0,0), (10000,80), (245,117,16), -1)
        
        # Display Repetitions
        cv2.putText(image, 'Repetitions', (300,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, str(cnt), 
                    (310,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Curl Stage data
        cv2.putText(image, 'Curl Stage', (900,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, curl_stage, 
                    (890,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_styled_landmarks_right(frame, results)

# %%
plt.figure(figsize=(12,6))
cv2.putText(frame, str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
# Left Arm

cap = cv2.VideoCapture(0)
cnt = 0
curl_stage = None

# Access mediapipe model
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
# Set mediapipe model 
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = pose.process(image)
        
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw landmarks
        draw_styled_landmarks_left(image, results)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            face = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            # Calculate percentage
            obj = Rating(hip,shoulder,elbow)
            percentage = obj.calculate_rating()
            the_angle = obj.calculate_angle()
            
            if percentage > 80:
                cv2.putText(image, "Great: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            if percentage < 80 and percentage > 60:
                cv2.putText(image, "Could be better: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            if percentage < 60 and the_angle > 5:
                cv2.putText(image, "Please adjust your arm: " + str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
            
            # Calculate angle for counter
            obj1 = Rating(shoulder,elbow,wrist)
            angle = obj1.calculate_angle()
            
            if angle > 150 and percentage > 80:
                curl_stage = 'down'
            if angle < 40 and curl_stage == 'down':
                curl_stage = 'up'
                cnt += 1
                
        except:
            pass
        
        # Rectangle Setup on Top
        cv2.rectangle(image, (0,0), (10000,80), (245,117,16), -1)
        
        # Display Repetitions
        cv2.putText(image, 'Repetitions', (300,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, str(cnt), 
                    (310,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Curl Stage data
        cv2.putText(image, 'Curl Stage', (900,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, curl_stage, 
                    (890,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_styled_landmarks_left(frame, results)

# %%
plt.figure(figsize=(12,6))
cv2.putText(frame, str(round(percentage, 2)) + '%', 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA
                                )
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
